# %% [markdown]
# # Excel functions

# %% [markdown]
# 1. Explain the difference between relative ,absolute and mix cell referencing you have the following dataset: vehicle   price
#  vehicle   price
#   car      500000           bicycle   10500     auto rikshaw  25000                                                                          Ans. 1. Relative Cell Reference
# Example: A1
# Behavior: Changes automatically when you copy the formula to another cell.
#
# Example:
# If you write =A1+B1 in row 1 and copy it down to row 2, it becomes:
#
# =A2+B2                                                                              2. Absolute Cell Reference
# Example: $A$1
# Behavior: Does not change when copied.
#
# Example:
# If you write =$A$1+B1 and copy it down:
#
# $A$1 stays fixed
# B1 changes to B2, B3, etc.                                                                             3. Mixed Cell Referencing ($D1 or D$1)
# Case 1: D$1 (Row fixed)
# =B2*D$1
# Row 1 is fixed, column can change
# Useful if copying formula across columns
# Case 2: $D1 (Column fixed)
# =B2*$D1
# Column D is fixed, row changes
# Useful if copying formula down with multiple rows of rates3. Mixed Cell Referencing ($D1 or D$1)
# Case 1: D$1 (Row fixed)
# =B2*D$1
# Row 1 is fixed, column can change
# Useful if copying formula across columns
# Case 2: $D1 (Column fixed)
# =B2*$D1
# Column D is fixed, row changes
# Useful if copying formula down with multiple rows of rates                                                                                                                                                                                                                                            Key Differences ( Example)
# Type	Example Formula	What Changes When Copied
# Relative	=B2*D1	Both row & column change
# Absolute	=B2*$D$1	Nothing changes (fixed)
# Mixed	=B2*D$1	Column changes, row fixed
# Mixed	=B2*$D1	Row changes, column fixed                                                                                                                                                                                                                                                                                                                            2. Write a formulato calculate the total sales of car and bicycle only.                                                                            Ans- Formula to calculate total sales of Car + Bicycle only
# ✔ Simple direct formula:
# =B2+B3
#
#  This adds:
#
# Car (B2)
# Bicycle (B3)
#  Alternative (more flexible using condition)
#
# If you want a smarter formula (useful for larger data):
#
# =SUMIF(A2:A4,"Car",B2:B4) + SUMIF(A2:A4,"Bicycle",B2:B4)
# This finds and adds only:
#
# "Car"
# "Bicycle"
#  Final Answer:
#
# Total = 500000 + 10500 = 510500                                                                                                                                                           3. Using the data below, write a formula to calculate the average sales of items priced above 100 but less then 300.                                                                                  items   a   b             c                                                                              price  90,150,250                                                                          sales 1000,1200,1500 .                                                                                                                                                           Ans-Find the average sales where price > 100 and < 300
#
#  Prices that match condition:
#
# 150
# 250
# 90  (excluded)
#
#  Corresponding sales:
#
# 1200
# 1500
#  Formula:
# =AVERAGEIFS(B2:D2, B1:D1, ">100", B1:D1, "<300")
#  Result:
# (
# 1200
# +
# 1500
# )
# /
# 2
# =
# 1350
# (1200+1500)/2=1350
# Explanation:
# B2:D2 → Sales range
# B1:D1 → Price range
# ">100" → Condition 1
# "<300" → Condition 2
#
# Datasetlink:Sales data
# 4.count how many customer names are recorded.
# There are 50 customer names recorded.
#
# Reason:
#
# OrderIDs run from 1001 to 1050
# Each order has one customer name
# Total records = 50 customers
#
# salesdata link
# "C:\Users\dell\Downloads\sales data.xlsx"
